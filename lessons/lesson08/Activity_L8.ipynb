# %% [markdown]
# In-Class Activity: Data Exploration, Summary Statistics & Outliers
# 1. Load irish.csv
#
# Make sure irish.csv is in the same folder as your notebook.

# %% [markdown]
# Exercise 2
#
# What do you notice about the dataset?
#
# Write 1–2 observations in a Markdown cell.

# %% [markdown]
# Data Analyst Challenge
#
# Your manager asks:
#
# "Are there unusual observations in our dataset, and what should we report about them?"
#
# You must prepare a short analysis.
#
# Your report must include:
#
# 1. Dataset exploration
#
# Number of rows
# Number of columns
# Important variables
#
# 2. Summary statistics
#
# Mean
# Median
# Minimum
# Maximum
# Standard deviation
#
# 3. IQR analysis
#
# Q1
# Q3
# IQR
# Lower bound
# Upper bound
# Number of potential outliers
#
# 4. Z-score analysis
#
# Number of potential outliers
# One example of an unusually high or low Z-score
#
# 5. Comparison
#
# Explain whether the two methods produced similar results.
#
# 6. Interpretation
#
# Explain what the results mean in the context of the dataset.
