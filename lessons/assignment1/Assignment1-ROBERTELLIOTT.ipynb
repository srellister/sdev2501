# %% [markdown]
# ====================================================================
# Course:      SDEV 2171 - Software Development Practice
# Assignment:  Assignment 01 - Coding in Notebooks
# Author:      Robert Elliott
# Date:        September 21, 2026
# Instructor:  Shauli Sumi
# ====================================================================

# %% [markdown]
# Import the required libraries to the notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ingest the dataset from the Edmonton's OpenData portal

# %%
uri1 = "../../data/Historical_Parkade_Openspace_Data_20260921.csv"
uri2 = "../../data/Edmonton_Business_Census_-_Neighbourhood_Aggregation_20260921.csv"
uri3 = "../../data/Weather_Data_(Daily)_-_Environment_Canada_20260921.csv"

df = pd.read_csv(uri2)

# %% [markdown]
# Display the first five rows of the dataset

# %%
df.head()
# Out:
#   Neighbourhood Name Neighbourhood Number  \
# 0        PLACE LARUE                4,400
# 1             FRASER                2,280
# 2    QUEEN ALEXANDRA                5,330
# 3            ELMWOOD                4,140
# 4           KILKENNY                2,410
#
#                                             Geometry  Survey Year  \
# 0  POLYGON ((-113.63538478306816 53.5374800402340...         2024
# 1  POLYGON ((-113.36909883943375 53.6068174173811...         2025
# 2  POLYGON ((-113.51204398532501 53.5181009116741...         2025
# 3  POLYGON ((-113.61531596556004 53.5195544722557...         2024
# 4  POLYGON ((-113.44280850377078 53.6048438749594...         2025
#
#   Number of Businesses Number of Employees
# 0                  103               3,316
# 1                    8                 104
# 2                  237               2,580
# 3                    4                  28
# 4                   31                 590

# %% [markdown]
# Display the shape of the dataset

# %%
print("The shape of the dataset in [columns, rows]", df.shape)
# Out:
# The shape of the dataset in [columns, rows] (545, 6)

# %% [markdown]
# The columns datatypes

# %%
print("Datatypes: ", df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Neighbourhood Name    545 non-null    str
#  1   Neighbourhood Number  545 non-null    str
#  2   Geometry              545 non-null    str
#  3   Survey Year           545 non-null    int64
#  4   Number of Businesses  545 non-null    str
#  5   Number of Employees   545 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 2.5 MB
# Datatypes:  None

# %% [markdown]
# For 2 numerical columns, compute:
# Mean, median, mode, range, variance, standard deviation, quartiles(Q1, Q3), IQR

# %%
df["Number of Employees"].describe()
# Out:
# count     545
# unique    468
# top        30
# freq        5
# Name: Number of Employees, dtype: object

# %%
df["Total Spaces"].describe()
# Out:
# count     657315
# unique        15
# top          161
# freq      131594
# Name: Total Spaces, dtype: int64
